# %% [markdown]
# # Jastrow Factor Derivatives
#
# This notebook calculates the expressions for the derivatives of the following Jastrow function:
#
# $$J(X) = \prod_{i < j} \exp\left(-\frac{\beta^2}{2}r_{ij}^2 + |\beta\gamma|r_{ij}\right)$$
#
# with $N$ particles in $D$ dimensions, $\mathbf{X}\in\mathbb{R}^{N\times D}$ and $r_{ij} = ||\mathbf{X_i} - \mathbf{X_j}||$.

# %%
# %reload_ext blackcellmagic
from sympy import *
init_printing()

# %%
N, D, i, j, k, l, d = symbols("N D i j k l d", integer=True)
X = IndexedBase("X", shape=(N, D))

# %% [markdown]
# ## Definition

# %%
def r(i, j):
    return sqrt(Sum((X[i, d] - X[j, d]) ** 2, (d, 1, D)))


# r = Function('r', positive=True)


def J(X):
    beta, gamma = symbols(r"\beta \gamma", real=True)
    exponent = Sum(
        -beta ** 2 / 2 * r(i, j) ** 2 + Abs(beta * gamma) * r(i, j),
        (i, 1, N - 1),
        (j, i + 1, N),
    )
    return exp(exponent), (beta, gamma)


Jastrow, (beta, gamma) = J(X)
Jastrow
# Out:
#      N      N - 1
#   ________ ________
#   ╲        ╲
#    ╲        ╲       ⎛           D
#     ╲        ╲      ⎜          ___
#      ╲        ╲     ⎜          ╲
#       ╲        ╲    ⎜       2   ╲                      2
#        ╲        ╲   ⎜  \beta ⋅  ╱   (X[i, d] - X[j, d])
#         ╲        ╲  ⎜          ╱
#         ╱        ╱  ⎜          ‾‾‾
#        ╱        ╱   ⎜         d = 1
#       ╱        ╱    ⎜- ───────────────────────────────── + │\beta⋅\gamma│⋅
#      ╱        ╱     ⎜                  2                                     ╱
#     ╱        ╱      ⎜                                                       ╱
#    ╱        ╱       ⎝                                                     ╲╱
#   ╱        ╱
#   ‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾
#  j = i + 1  i = 1
# ℯ
#
#
#
#
#                                  ⎞
#                                  ⎟
#                                  ⎟
#      ____________________________⎟
#     ╱   D                        ⎟
#    ╱   ___                       ⎟
#   ╱    ╲                         ⎟
#  ╱      ╲                      2 ⎟
# ╱       ╱   (X[i, d] - X[j, d])  ⎟
#        ╱                         ⎟
#        ‾‾‾                       ⎟
#       d = 1                      ⎠

# %%
log_Jastrow = expand_log(log(Jastrow), force=True)
log_Jastrow
# Out:
#     N      N - 1
#  ________ ________
#  ╲        ╲
#   ╲        ╲       ⎛           D
#    ╲        ╲      ⎜          ___
#     ╲        ╲     ⎜          ╲
#      ╲        ╲    ⎜       2   ╲                      2
#       ╲        ╲   ⎜  \beta ⋅  ╱   (X[i, d] - X[j, d])
#        ╲        ╲  ⎜          ╱
#        ╱        ╱  ⎜          ‾‾‾
#       ╱        ╱   ⎜         d = 1
#      ╱        ╱    ⎜- ───────────────────────────────── + │\beta⋅\gamma│⋅    ╱
#     ╱        ╱     ⎜                  2                                     ╱
#    ╱        ╱      ⎜                                                       ╱
#   ╱        ╱       ⎝                                                     ╲╱
#  ╱        ╱
#  ‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾
# j = i + 1  i = 1
#
#
#
#
#                                 ⎞
#                                 ⎟
#                                 ⎟
#     ____________________________⎟
#    ╱   D                        ⎟
#   ╱   ___                       ⎟
#  ╱    ╲                         ⎟
# ╱      ╲                      2 ⎟
#        ╱   (X[i, d] - X[j, d])  ⎟
#       ╱                         ⎟
#       ‾‾‾                       ⎟
#      d = 1                      ⎠

# %% [markdown]
# ## Derivative w.r.t. $\gamma$

# %%
dlogJ_dGamma = diff(log_Jastrow, gamma, 1)
dlogJ_dGamma
# Out:
#     N      N - 1
#  _______  _______
#  ╲        ╲
#   ╲        ╲                                        __________________________
#    ╲        ╲                                      ╱   D
#     ╲        ╲                                    ╱   ___
#      ╲        ╲                                  ╱    ╲
#       ╲        ╲                                ╱      ╲
#       ╱        ╱  \beta⋅sign(\beta⋅\gamma)⋅    ╱       ╱   (X[i, d] - X[j, d])
#      ╱        ╱                               ╱       ╱
#     ╱        ╱                               ╱        ‾‾‾
#    ╱        ╱                              ╲╱        d = 1
#   ╱        ╱
#  ╱        ╱
#  ‾‾‾‾‾‾‾  ‾‾‾‾‾‾‾
# j = i + 1  i = 1
#
#
#
#
# __
#
#
#
# 2

# %% [markdown]
# ## Derivative w.r.t. $\beta$

# %%
dlogJ_dBeta = diff(log_Jastrow, beta, 1)
dlogJ_dBeta
# Out:
#     N      N - 1
#  _______  _______
#  ╲        ╲
#   ╲        ╲      ⎛
#    ╲        ╲     ⎜          D
#     ╲        ╲    ⎜         ___
#      ╲        ╲   ⎜         ╲
#       ╲        ╲  ⎜          ╲                      2
#       ╱        ╱  ⎜- \beta⋅  ╱   (X[i, d] - X[j, d])  + \gamma⋅sign(\beta⋅\gam
#      ╱        ╱   ⎜         ╱
#     ╱        ╱    ⎜         ‾‾‾
#    ╱        ╱     ⎝        d = 1
#   ╱        ╱
#  ╱        ╱
#  ‾‾‾‾‾‾‾  ‾‾‾‾‾‾‾
# j = i + 1  i = 1
#
#
#
#
#              ____________________________⎞
#             ╱   D                        ⎟
#            ╱   ___                       ⎟
#           ╱    ╲                         ⎟
#          ╱      ╲                      2 ⎟
# ma)⋅    ╱       ╱   (X[i, d] - X[j, d])  ⎟
#        ╱       ╱                         ⎟
#       ╱        ‾‾‾                       ⎟
#     ╲╱        d = 1                      ⎠

# %% [markdown]
# ## Derivative w.r.t. $X_{kl}$

# %%
dlogJ_dXkl = diff(log_Jastrow, X[k, l], 1)
dlogJ_dXkl
# Out:
#      N         N - 1
# ___________ ___________
# ╲           ╲
#  ╲           ╲          ⎛           D
#   ╲           ╲         ⎜          ___
#    ╲           ╲        ⎜          ╲
#     ╲           ╲       ⎜       2   ╲   ⎛2⋅δ   ⋅δ    - 2⋅δ   ⋅δ   ⎞⋅(X[i, d] -
#      ╲           ╲      ⎜  \beta ⋅  ╱   ⎝   d,l  i,k      d,l  j,k⎠
#       ╲           ╲     ⎜          ╱
#        ╲           ╲    ⎜          ‾‾‾
#         ╲           ╲   ⎜         d = 1
#          ╲           ╲  ⎜- ───────────────────────────────────────────────────
#          ╱           ╱  ⎜                               2
#         ╱           ╱   ⎜
#        ╱           ╱    ⎜
#       ╱           ╱     ⎜
#      ╱           ╱      ⎜
#     ╱           ╱       ⎜
#    ╱           ╱        ⎜
#   ╱           ╱         ⎜
#  ╱           ╱          ⎝
# ╱           ╱
# ‾‾‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾‾‾
#  j = i + 1     i = 1
#
#
#
#
#                              D
#                             ___
#                             ╲
#  X[j, d])                    ╲   ⎛2⋅δ   ⋅δ    - 2⋅δ   ⋅δ   ⎞⋅(X[i, d] - X[j, d
#             │\beta⋅\gamma│⋅  ╱   ⎝   d,l  i,k      d,l  j,k⎠
#                             ╱
#                             ‾‾‾
#                            d = 1
# ───────── + ──────────────────────────────────────────────────────────────────
#                                      ____________________________
#                                     ╱   D
#                                    ╱   ___
#                                   ╱    ╲
#                                  ╱      ╲                      2
#                           2⋅    ╱       ╱   (X[i, d] - X[j, d])
#                                ╱       ╱
#                               ╱        ‾‾‾
#                             ╲╱        d = 1
#
#
#
#
#
#
#
#   ⎞
#   ⎟
#   ⎟
# ])⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
# ──⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎟
#   ⎠

# %%
# Manually simplify the above:
dlogJ_dXkl = Sum(
    (KroneckerDelta(k, i) - KroneckerDelta(k, j))
    * (X[i, l] - X[j, l])
    * (-beta ** 2 + Abs(beta * gamma) / r(i, j)),
    (i, 1, N - 1),
    (j, i + 1, N),
)
dlogJ_dXkl
# Out:
#     N      N - 1
#  ________ ________
#  ╲        ╲
#   ╲        ╲       ⎛       2               │\beta⋅\gamma│           ⎞
#    ╲        ╲      ⎜- \beta  + ─────────────────────────────────────⎟⋅⎛δ    -
#     ╲        ╲     ⎜                    ____________________________⎟ ⎝ i,k
#      ╲        ╲    ⎜                   ╱   D                        ⎟
#       ╲        ╲   ⎜                  ╱   ___                       ⎟
#        ╲        ╲  ⎜                 ╱    ╲                         ⎟
#        ╱        ╱  ⎜                ╱      ╲                      2 ⎟
#       ╱        ╱   ⎜               ╱       ╱   (X[i, d] - X[j, d])  ⎟
#      ╱        ╱    ⎜              ╱       ╱                         ⎟
#     ╱        ╱     ⎜             ╱        ‾‾‾                       ⎟
#    ╱        ╱      ⎝           ╲╱        d = 1                      ⎠
#   ╱        ╱
#  ╱        ╱
#  ‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾
# j = i + 1  i = 1
#
#
#
#
#
# δ   ⎞⋅(X[i, l] - X[j, l])
#  j,k⎠

# %% [markdown]
# ## Second derivative w.r.t. $X_{kl}$

# %%
d2J_dXkl2 = dlogJ_dXkl ** 2 + diff(dlogJ_dXkl, X[k, l], 1)
d2J_dXkl2
# Out:
#
#
#
# ⎛    N      N - 1
# ⎜ ________ ________
# ⎜ ╲        ╲
# ⎜  ╲        ╲       ⎛       2               │\beta⋅\gamma│           ⎞
# ⎜   ╲        ╲      ⎜- \beta  + ─────────────────────────────────────⎟⋅⎛δ    -
# ⎜    ╲        ╲     ⎜                    ____________________________⎟ ⎝ i,k
# ⎜     ╲        ╲    ⎜                   ╱   D                        ⎟
# ⎜      ╲        ╲   ⎜                  ╱   ___                       ⎟
# ⎜       ╲        ╲  ⎜                 ╱    ╲                         ⎟
# ⎜       ╱        ╱  ⎜                ╱      ╲                      2 ⎟
# ⎜      ╱        ╱   ⎜               ╱       ╱   (X[i, d] - X[j, d])  ⎟
# ⎜     ╱        ╱    ⎜              ╱       ╱                         ⎟
# ⎜    ╱        ╱     ⎜             ╱        ‾‾‾                       ⎟
# ⎜   ╱        ╱      ⎝           ╲╱        d = 1                      ⎠
# ⎜  ╱        ╱
# ⎜ ╱        ╱
# ⎜ ‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾
# ⎝j = i + 1  i = 1
#
#
#
#
#                                     N         N - 1
#                                ___________ ___________
#                            2   ╲           ╲
#                           ⎞     ╲           ╲          ⎛
#                           ⎟      ╲           ╲         ⎜
#                           ⎟       ╲           ╲        ⎜
#                           ⎟        ╲           ╲       ⎜
#  δ   ⎞⋅(X[i, l] - X[j, l])⎟         ╲           ╲      ⎜
#   j,k⎠                    ⎟          ╲           ╲     ⎜
#                           ⎟           ╲           ╲    ⎜
#                           ⎟            ╲           ╲   ⎜⎛       2
#                           ⎟             ╲           ╲  ⎜⎜- \beta  + ──────────
#                           ⎟  +          ╱           ╱  ⎜⎜                    _
#                           ⎟            ╱           ╱   ⎜⎜                   ╱
#                           ⎟           ╱           ╱    ⎜⎜                  ╱
#                           ⎟          ╱           ╱     ⎜⎜                 ╱
#                           ⎟         ╱           ╱      ⎜⎜                ╱
#                           ⎟        ╱           ╱       ⎜⎜               ╱
#                           ⎟       ╱           ╱        ⎜⎜              ╱
#                           ⎟      ╱           ╱         ⎜⎜             ╱
#                           ⎠     ╱           ╱          ⎝⎝           ╲╱
#                                ╱           ╱
#                                ‾‾‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾‾‾
#                                 j = i + 1     i = 1
#
#
#
#
#
#
#
#
#                                               ⎛δ    - δ   ⎞⋅(X[i, l] - X[j, l]
#                                               ⎝ i,k    j,k⎠
#
#   │\beta⋅\gamma│           ⎞              2
# ───────────────────────────⎟⋅⎛δ    - δ   ⎞  - ────────────────────────────────
# ___________________________⎟ ⎝ i,k    j,k⎠
#   D                        ⎟
#  ___                       ⎟
#  ╲                         ⎟
#   ╲                      2 ⎟
#   ╱   (X[i, d] - X[j, d])  ⎟
#  ╱                         ⎟
#  ‾‾‾                       ⎟
# d = 1                      ⎠
#
#
#
#
#
#
#
#                    D                                                  ⎞
#                   ___                                                 ⎟
#                   ╲                                                   ⎟
#                    ╲   ⎛2⋅δ   ⋅δ    - 2⋅δ   ⋅δ   ⎞⋅(X[i, d] - X[j, d])⎟
# )⋅│\beta⋅\gamma│⋅  ╱   ⎝   d,l  i,k      d,l  j,k⎠                    ⎟
#                   ╱                                                   ⎟
#                   ‾‾‾                                                 ⎟
#                  d = 1                                                ⎟
# ──────────────────────────────────────────────────────────────────────⎟
#                                 3/2                                   ⎟
#     ⎛  D                       ⎞                                      ⎟
#     ⎜ ___                      ⎟                                      ⎟
#     ⎜ ╲                        ⎟                                      ⎟
#     ⎜  ╲                      2⎟                                      ⎟
#   2⋅⎜  ╱   (X[i, d] - X[j, d]) ⎟                                      ⎟
#     ⎜ ╱                        ⎟                                      ⎟
#     ⎜ ‾‾‾                      ⎟                                      ⎟
#     ⎝d = 1                     ⎠                                      ⎠

# %%
# Manually simplify the above:
d2J_dXkl2 = dlogJ_dXkl ** 2 + Sum(
    (KroneckerDelta(k, i) - KroneckerDelta(k, j)) ** 2
    * (-beta ** 2 + Abs(beta * gamma) / r(i, j))
    - (KroneckerDelta(k, i) - KroneckerDelta(k, j))
    * (X[i, l] - X[j, l]) ** 2
    * Abs(beta * gamma)
    / r(i, j) ** 3,
    (i, 1, N - 1),
    (j, i + 1, N),
)
d2J_dXkl2
# Out:
#
# ⎛    N      N - 1
# ⎜ ________ ________
# ⎜ ╲        ╲
# ⎜  ╲        ╲       ⎛       2               │\beta⋅\gamma│           ⎞
# ⎜   ╲        ╲      ⎜- \beta  + ─────────────────────────────────────⎟⋅⎛δ    -
# ⎜    ╲        ╲     ⎜                    ____________________________⎟ ⎝ i,k
# ⎜     ╲        ╲    ⎜                   ╱   D                        ⎟
# ⎜      ╲        ╲   ⎜                  ╱   ___                       ⎟
# ⎜       ╲        ╲  ⎜                 ╱    ╲                         ⎟
# ⎜       ╱        ╱  ⎜                ╱      ╲                      2 ⎟
# ⎜      ╱        ╱   ⎜               ╱       ╱   (X[i, d] - X[j, d])  ⎟
# ⎜     ╱        ╱    ⎜              ╱       ╱                         ⎟
# ⎜    ╱        ╱     ⎜             ╱        ‾‾‾                       ⎟
# ⎜   ╱        ╱      ⎝           ╲╱        d = 1                      ⎠
# ⎜  ╱        ╱
# ⎜ ╱        ╱
# ⎜ ‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾
# ⎝j = i + 1  i = 1
#
#
#                            2       N       N - 1
#                           ⎞    _________ _________
#                           ⎟    ╲         ╲
#                           ⎟     ╲         ╲        ⎛
#                           ⎟      ╲         ╲       ⎜
#  δ   ⎞⋅(X[i, l] - X[j, l])⎟       ╲         ╲      ⎜⎛       2               │\
#   j,k⎠                    ⎟        ╲         ╲     ⎜⎜- \beta  + ──────────────
#                           ⎟         ╲         ╲    ⎜⎜                    _____
#                           ⎟          ╲         ╲   ⎜⎜                   ╱   D
#                           ⎟           ╲         ╲  ⎜⎜                  ╱   ___
#                           ⎟  +        ╱         ╱  ⎜⎜                 ╱    ╲
#                           ⎟          ╱         ╱   ⎜⎜                ╱      ╲
#                           ⎟         ╱         ╱    ⎜⎜               ╱       ╱
#                           ⎟        ╱         ╱     ⎜⎜              ╱       ╱
#                           ⎟       ╱         ╱      ⎜⎜             ╱        ‾‾‾
#                           ⎟      ╱         ╱       ⎝⎝           ╲╱        d =
#                           ⎟     ╱         ╱
#                           ⎟    ╱         ╱
#                           ⎠    ‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾
#                                j = i + 1   i = 1
#
#
#
#
#                                                                            2
#                                           ⎛δ    - δ   ⎞⋅(X[i, l] - X[j, l]) ⋅│
# beta⋅\gamma│           ⎞              2   ⎝ i,k    j,k⎠
# ───────────────────────⎟⋅⎛δ    - δ   ⎞  - ────────────────────────────────────
# _______________________⎟ ⎝ i,k    j,k⎠
#                        ⎟                           ⎛  D
#                        ⎟                           ⎜ ___
#                        ⎟                           ⎜ ╲
#                      2 ⎟                           ⎜  ╲                      2
#   (X[i, d] - X[j, d])  ⎟                           ⎜  ╱   (X[i, d] - X[j, d])
#                        ⎟                           ⎜ ╱
#                        ⎟                           ⎜ ‾‾‾
# 1                      ⎠                           ⎝d = 1
#
#
#
#
#
#
#
#
#              ⎞
# \beta⋅\gamma│⎟
#              ⎟
# ─────────────⎟
#  3/2         ⎟
# ⎞            ⎟
# ⎟            ⎟
# ⎟            ⎟
# ⎟            ⎟
# ⎟            ⎟
# ⎟            ⎟
# ⎟            ⎟
# ⎠            ⎠
