# %% [markdown]
# # Jastrow Factor Derivatives
#
# This notebook calculates the expressions for the derivatives of the following Jastrow function:
#
# $$J(\mathbf{X}) = \prod_{i < j} \exp\left[- \frac{1}{2}\left(\frac{\beta}{r}\right)^m  \right]$$
#
# with $N$ particles in $D$ dimensions, $\mathbf{X}\in\mathbb{R}^{N\times D}$ and $r_{ij} = ||\mathbf{X_i} - \mathbf{X_j}||$.

# %%
# %reload_ext blackcellmagic
from sympy import *
init_printing()

# %%
N, D, i, j, k, l, d = symbols("N D i j k l d", integer=True)
X = IndexedBase("X", shape=(N, D))

# %% [markdown]
# ## Definition

# %%
class r(Function):
    @classmethod
    def eval(cls, i, j):
        if i.is_Number and j.is_Number:
            return sqrt(Sum((X[i, d] - X[j, d]) ** 2, (d, 1, D)))

    def doit(self, **kwargs):
        i, j = self.args
        return sqrt(Sum((X[i, d] - X[j, d]) ** 2, (d, 1, D)))

    def _eval_derivative(self, x):
        return self.doit()._eval_derivative(x)


def J(X):
    beta = symbols(r"\beta", real=True, positive=True)
    n = symbols("n", integer=True, positive=True)
    exponent = Sum(-(beta / r(i, j)) ** n / 2, (i, 1, N - 1), (j, i + 1, N))
    return exp(exponent), (beta, n)


Jastrow, (beta, n) = J(X)
Jastrow
# Out:
#      N     N - 1
#    _____   _____
#    ╲       ╲
#     ╲       ╲              n
#      ╲       ╲    ⎛ \beta ⎞
#       ╲       ╲  -⎜───────⎟
#       ╱       ╱   ⎝r(i, j)⎠
#      ╱       ╱   ────────────
#     ╱       ╱         2
#    ╱       ╱
#    ‾‾‾‾‾   ‾‾‾‾‾
#  j = i + 1 i = 1
# ℯ

# %%
log_Jastrow = expand_log(log(Jastrow), force=True)
log_Jastrow
# Out:
#     N     N - 1
#   _____   _____
#   ╲       ╲
#    ╲       ╲              n
#     ╲       ╲    ⎛ \beta ⎞
#      ╲       ╲  -⎜───────⎟
#      ╱       ╱   ⎝r(i, j)⎠
#     ╱       ╱   ────────────
#    ╱       ╱         2
#   ╱       ╱
#   ‾‾‾‾‾   ‾‾‾‾‾
# j = i + 1 i = 1

# %% [markdown]
# ## Derivative w.r.t. $\beta$

# %%
dlogJ_dBeta = diff(log_Jastrow, beta, 1)
dlogJ_dBeta.simplify()
# Out:
#               N     N - 1
#              ___     ___
#              ╲       ╲
#       n       ╲       ╲    -n
# -\beta ⋅n⋅    ╱       ╱   r  (i, j)
#              ╱       ╱
#              ‾‾‾     ‾‾‾
#           j = i + 1 i = 1
# ────────────────────────────────────
#               2⋅\beta

# %% [markdown]
# ## Derivative w.r.t. $X_{kl}$

# %%
dlogJ_dXkl = diff(log_Jastrow.doit(), X[k, l], 1)
dlogJ_dXkl
# Out:
#       N            N - 1
# ______________ ______________
# ╲              ╲
#  ╲              ╲                                                          D
#   ╲              ╲                                                        ___
#    ╲              ╲                                                    n  ╲
#     ╲              ╲            ⎛                \beta                ⎞    ╲
#      ╲              ╲         n⋅⎜─────────────────────────────────────⎟ ⋅  ╱
#       ╲              ╲          ⎜         ____________________________⎟   ╱
#        ╲              ╲         ⎜        ╱   D                        ⎟   ‾‾‾
#         ╲              ╲        ⎜       ╱   ___                       ⎟  d = 1
#          ╲              ╲       ⎜      ╱    ╲                         ⎟
#           ╲              ╲      ⎜     ╱      ╲                      2 ⎟
#            ╲              ╲     ⎜    ╱       ╱   (X[i, d] - X[j, d])  ⎟
#             ╲              ╲    ⎜   ╱       ╱                         ⎟
#             ╱              ╱    ⎜  ╱        ‾‾‾                       ⎟
#            ╱              ╱     ⎝╲╱        d = 1                      ⎠
#           ╱              ╱    ────────────────────────────────────────────────
#          ╱              ╱                                           D
#         ╱              ╱                                           ___
#        ╱              ╱                                            ╲
#       ╱              ╱                                              ╲
#      ╱              ╱                                           4⋅  ╱   (X[i,
#     ╱              ╱                                               ╱
#    ╱              ╱                                                ‾‾‾
#   ╱              ╱                                                d = 1
#  ╱              ╱
# ╱              ╱
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾‾‾‾‾‾
#   j = i + 1        i = 1
#
#
#
#
#
#
#
#  ⎛2⋅δ   ⋅δ    - 2⋅δ   ⋅δ   ⎞⋅(X[i, d] - X[j, d])
#  ⎝   d,l  i,k      d,l  j,k⎠
#
#
#
#
#
#
#
#
#
# ────────────────────────────────────────────────
#
#
#
#              2
# d] - X[j, d])

# %%
# Manually simplify the above:
dlogJ_dXkl = Sum(
    n / 2
    * (beta / r(i, j)) ** n
    * (KroneckerDelta(k, i) - KroneckerDelta(k, j))
    * (X[i, l] - X[j, l])
    / (r(i, j).doit() ** 2),
    (i, 1, N - 1),
    (j, i + 1, N),
)
dlogJ_dXkl
# Out:
#     N       N - 1
# _________ _________
# ╲         ╲
#  ╲         ╲                   n
#   ╲         ╲         ⎛ \beta ⎞
#    ╲         ╲      n⋅⎜───────⎟ ⋅⎛δ    - δ   ⎞⋅(X[i, l] - X[j, l])
#     ╲         ╲       ⎝r(i, j)⎠  ⎝ i,k    j,k⎠
#      ╲         ╲    ──────────────────────────────────────────────
#       ╲         ╲                D
#        ╲         ╲              ___
#        ╱         ╱              ╲
#       ╱         ╱                ╲                      2
#      ╱         ╱             2⋅  ╱   (X[i, d] - X[j, d])
#     ╱         ╱                 ╱
#    ╱         ╱                  ‾‾‾
#   ╱         ╱                  d = 1
#  ╱         ╱
# ╱         ╱
# ‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾
# j = i + 1   i = 1

# %% [markdown]
# ## Second derivative w.r.t. $X_{kl}$

# %%
d2J_dXkl2 = dlogJ_dXkl ** 2 + diff(dlogJ_dXkl, X[k, l], 1)
d2J_dXkl2
# Out:
#                                                                              N
#                                                                     2   ______
# ⎛    N       N - 1                                                 ⎞    ╲
# ⎜_________ _________                                               ⎟     ╲
# ⎜╲         ╲                                                       ⎟      ╲
# ⎜ ╲         ╲                   n                                  ⎟       ╲
# ⎜  ╲         ╲         ⎛ \beta ⎞                                   ⎟        ╲
# ⎜   ╲         ╲      n⋅⎜───────⎟ ⋅⎛δ    - δ   ⎞⋅(X[i, l] - X[j, l])⎟         ╲
# ⎜    ╲         ╲       ⎝r(i, j)⎠  ⎝ i,k    j,k⎠                    ⎟
# ⎜     ╲         ╲    ──────────────────────────────────────────────⎟
# ⎜      ╲         ╲                D                                ⎟
# ⎜       ╲         ╲              ___                               ⎟
# ⎜       ╱         ╱              ╲                                 ⎟  +
# ⎜      ╱         ╱                ╲                      2         ⎟
# ⎜     ╱         ╱             2⋅  ╱   (X[i, d] - X[j, d])          ⎟
# ⎜    ╱         ╱                 ╱                                 ⎟
# ⎜   ╱         ╱                  ‾‾‾                               ⎟         ╱
# ⎜  ╱         ╱                  d = 1                              ⎟        ╱
# ⎜ ╱         ╱                                                      ⎟       ╱
# ⎜╱         ╱                                                       ⎟      ╱
# ⎜‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾                                               ⎟     ╱
# ⎝j = i + 1   i = 1                                                 ⎠    ╱
#                                                                         ‾‾‾‾‾‾
#                                                                          j = i
#
#          N - 1
# _____ ___________
#       ╲
#        ╲          ⎛
#         ╲         ⎜
#          ╲        ⎜                                          n
#           ╲       ⎜                                 ⎛ \beta ⎞
#            ╲      ⎜           n                   n⋅⎜───────⎟ ⋅⎛δ    - δ   ⎞⋅(
# ╲           ╲     ⎜  ⎛ \beta ⎞               2      ⎝r(i, j)⎠  ⎝ i,k    j,k⎠
#  ╲           ╲    ⎜n⋅⎜───────⎟ ⋅⎛δ    - δ   ⎞
#   ╲           ╲   ⎜  ⎝r(i, j)⎠  ⎝ i,k    j,k⎠
#    ╲           ╲  ⎜──────────────────────────── - ────────────────────────────
#    ╱           ╱  ⎜    D
#   ╱           ╱   ⎜   ___
#  ╱           ╱    ⎜   ╲
# ╱           ╱     ⎜    ╲                      2
#            ╱      ⎜2⋅  ╱   (X[i, d] - X[j, d])
#           ╱       ⎜   ╱
#          ╱        ⎜   ‾‾‾
#         ╱         ⎜  d = 1
#        ╱          ⎝
#       ╱
# ‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾‾‾
#  + 1     i = 1
#
#
#
#
#                      D                                                  ⎞
#                     ___                                                 ⎟
#                     ╲                                                   ⎟
#                      ╲   ⎛2⋅δ   ⋅δ    - 2⋅δ   ⋅δ   ⎞⋅(X[i, d] - X[j, d])⎟
# X[i, l] - X[j, l])⋅  ╱   ⎝   d,l  i,k      d,l  j,k⎠                    ⎟
#                     ╱                                                   ⎟
#                     ‾‾‾                                                 ⎟
#                    d = 1                                                ⎟
# ────────────────────────────────────────────────────────────────────────⎟
#                                     2                                   ⎟
#         ⎛  D                       ⎞                                    ⎟
#         ⎜ ___                      ⎟                                    ⎟
#         ⎜ ╲                        ⎟                                    ⎟
#         ⎜  ╲                      2⎟                                    ⎟
#       2⋅⎜  ╱   (X[i, d] - X[j, d]) ⎟                                    ⎟
#         ⎜ ╱                        ⎟                                    ⎟
#         ⎜ ‾‾‾                      ⎟                                    ⎟
#         ⎝d = 1                     ⎠                                    ⎠

# %%
# Manually simplify the above:
d2J_dXkl2 = dlogJ_dXkl ** 2 + Sum(
    n / 2
    * (beta / r(i, j)) ** n
    / (r(i, j) ** 2)
    * (KroneckerDelta(k, i) - KroneckerDelta(k, j)) ** 2
    * (1 - 2 * (X[i, l] - X[j, l]) ** 2 / (r(i, j) ** 2)   ),
    (i, 1, N - 1),
    (j, i + 1, N),
)
d2J_dXkl2
# Out:
#
#
#
#
#     N     N - 1
#   ______  ______
#   ╲       ╲
#    ╲       ╲                n ⎛                       2    ⎞
#     ╲       ╲      ⎛ \beta ⎞  ⎜  2⋅(X[i, l] - X[j, l])     ⎟              2
#      ╲       ╲   n⋅⎜───────⎟ ⋅⎜- ────────────────────── + 1⎟⋅⎛δ    - δ   ⎞
#       ╲       ╲    ⎝r(i, j)⎠  ⎜          2                 ⎟ ⎝ i,k    j,k⎠
#       ╱       ╱               ⎝         r (i, j)           ⎠                +
#      ╱       ╱   ──────────────────────────────────────────────────────────
#     ╱       ╱                               2
#    ╱       ╱                             2⋅r (i, j)
#   ╱       ╱
#   ‾‾‾‾‾‾  ‾‾‾‾‾‾
# j = i + 1 i = 1
#
#
#
#
#                                                                     2
# ⎛    N       N - 1                                                 ⎞
# ⎜_________ _________                                               ⎟
# ⎜╲         ╲                                                       ⎟
# ⎜ ╲         ╲                   n                                  ⎟
# ⎜  ╲         ╲         ⎛ \beta ⎞                                   ⎟
# ⎜   ╲         ╲      n⋅⎜───────⎟ ⋅⎛δ    - δ   ⎞⋅(X[i, l] - X[j, l])⎟
# ⎜    ╲         ╲       ⎝r(i, j)⎠  ⎝ i,k    j,k⎠                    ⎟
# ⎜     ╲         ╲    ──────────────────────────────────────────────⎟
# ⎜      ╲         ╲                D                                ⎟
# ⎜       ╲         ╲              ___                               ⎟
# ⎜       ╱         ╱              ╲                                 ⎟
# ⎜      ╱         ╱                ╲                      2         ⎟
# ⎜     ╱         ╱             2⋅  ╱   (X[i, d] - X[j, d])          ⎟
# ⎜    ╱         ╱                 ╱                                 ⎟
# ⎜   ╱         ╱                  ‾‾‾                               ⎟
# ⎜  ╱         ╱                  d = 1                              ⎟
# ⎜ ╱         ╱                                                      ⎟
# ⎜╱         ╱                                                       ⎟
# ⎜‾‾‾‾‾‾‾‾‾ ‾‾‾‾‾‾‾‾‾                                               ⎟
# ⎝j = i + 1   i = 1                                                 ⎠
